# %% [markdown]
# <a href="https://colab.research.google.com/github/aadil279/DECD_Projeto/blob/main/Projeto_DECD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Imports

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import pandas as pd
import os

data_path = '/content/drive/MyDrive/Data/'

numero_ordens_servico_tabela          = pd.read_csv(data_path + 'numero-ordens-de-servico.csv', sep=';')
consumos_mensais_concelho_tabela      = pd.read_csv(data_path + 'consumos-mensais-concelho.csv', sep=';')
cpe_contratos_ativos_tabela           = pd.read_csv(data_path + 'cpe-contratos-ativos.csv', sep=';')
locais_consumo_baixa_tensao_tabela    = pd.read_csv(data_path + 'locais-consumo-baixa-tensao.csv', sep=';')
numero_contrato_tipo_contador_tabela  = pd.read_csv(data_path + 'numero-contrato-tipo-contador.csv', sep=';')

# %% [markdown]
# # **DATA PREPARATION**

# %% [markdown]
# ## **1) DATA CLEANING**
#
# ### Limpeza de dados das várias tabelas
#
# Constituído por 3 fases:
#
#
# 1.   Tratamento de Valores em Falta
# 2.   Processamento do conjunto de dados em conjuntos completamente categóricos e completamente numéricos
# 3.   Normalização de Dados

# %% [markdown]
# ### Tabela de Número de Ordens de Serviço Remoto
#
# Esta vai ser a nossa tabela base, portanto apenas retira-se o que não será utilizado de todo

# %%
# Observar os dados
numero_ordens_servico_tabela
# Out:
#          Ano  Mes     data    Distrito      Concelho  \
# 0       2022   12  2022-12  Portalegre  Ponte de Sôr
# 1       2022   12  2022-12  Portalegre  Ponte de Sôr
# 2       2022   12  2022-12  Portalegre  Ponte de Sôr
# 3       2022   12  2022-12  Portalegre  Ponte de Sôr
# 4       2022   12  2022-12  Portalegre    Portalegre
# ...      ...  ...      ...         ...           ...
# 200559  2023    9  2023-09      Lisboa        Lisboa
# 200560  2023    9  2023-09      Lisboa        Lisboa
# 200561  2023    9  2023-09      Lisboa        Lisboa
# 200562  2023    9  2023-09      Lisboa        Lisboa
# 200563  2023    9  2023-09      Lisboa        Lisboa
#
#                                                 Freguesia  \
# 0                                                Longomel
# 1                                               Montargil
# 2       União das freguesias de Ponte de Sor, Tramaga ...
# 3       União das freguesias de Ponte de Sor, Tramaga ...
# ...

# %%
# Verificar se existem valores em falta
numero_ordens_servico_tabela.isnull().sum()
# R: Não existem
# Out:
# Ano                              0
# Mes                              0
# data                             0
# Distrito                         0
# Concelho                         0
# Freguesia                        0
# Tipo de Serviço                  0
# Ordens Serviço Realizadas (#)    0
# CodDistritoConcelhoFreguesia     0
# dtype: int64

# %%
# Processamento de dados

# Conjunto de dados completamente categórico

# %% [markdown]
# ### Tabela de Consumos Mensais por Concelho

# %%
consumos_mensais_concelho_tabela

# %%
consumos_mensais_concelho_tabela.isnull().sum()

# %%
cpe_contratos_ativos_tabela.head(4)
# Out:
#     Ano  Mês CodDistritoConcelhoFreguesia Distrito                Concelho  \
# 0  2022    4                       131218    Porto                   Porto
# 1  2022    4                       060334  Coimbra                 Coimbra
# 2  2022    4                       031227    Braga  Vila Nova de Famalicão
# 3  2022    4                       010936   Aveiro    Santa Maria da Feira
#
#                                            Freguesia Tipo de Instalação  \
# 0  União das freguesias de Lordelo do Ouro e Mass...          Doméstico
# 1  União das freguesias de Coimbra (Sé Nova, Sant...          Doméstico
# 2                                               Nine          Doméstico
# 3  União das freguesias de São Miguel do Souto e ...          Doméstico
#
#          Nível de Tensão  CPEs (#)
# 0  Baixa Tensão Especial         7
# 1    Baixa Tensão Normal     10221
# 2    Baixa Tensão Normal         3
# 3  Baixa Tensão Especial         1

# %%
# ATENÇÃO! ISTO SÓ DEVE SER FEITO DEPOIS DO PRÉ-PROCESSAMENTO DAS TABELAS INDIVIDUAIS


# Juntar Numero de ordens de servico com consumos mensais por concelho
merged_tables = pd.merge(numero_ordens_servico_tabela, consumos_mensais_concelho_tabela[['CodDistritoConcelhoFreguesia', 'Data', 'Nível de Tensão', 'Energia Ativa (kWh)']],
                         left_on=["CodDistritoConcelhoFreguesia", "data"], right_on=["CodDistritoConcelhoFreguesia", "Data"])

# Retirar a coluna "Data", que é idêntica a 'data'
merged_tables.drop(columns=['Data'], inplace=True)


#Juntar
merged_tables
